# %%
name = "shashi"

# %%
tup = ('car', 'bike', 'car', 'bike', 'train', 'Bus')
tup.count('bike')
# Out:
# 2

# %%
tupl = ('car', 'bike', 'bike', 'train', 'bus', 'train')

# %%
max(tupl)
# Out:
# 'train'

# %%
min(tupl)
# Out:
# 'bike'

# %%
tup2 = (1.4,1.2,12,1.4,'celvin')

# %%
max(tup)
# Out:
# 'car'
