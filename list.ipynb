# %%
a= []
type(a)
# Out:
# list

# %%
b=list()
type(b)
# Out:
# list

# %%
lista={1,2344,6785858,648}
lista
# Out:
# {1, 648, 2344, 6785858}

# %%
fruits=('apple',13,'mango',15)
type(fruits)
# Out:
# tuple

# %%
friends = ['sha', 1, 1, 3.0,5,6]
friends[-1]
# Out:
# 6

# %%
friends[2:5]
# Out:
# [1, 3.0, 5]

# %%
v1= friends[0][2]

# %%
v2=friends[0]

# %%
v2
# Out:
# 'sha'

# %%
#add element to  list 3 diff methods [append,insert,extend]
friends=['sha', 1, 1, 3.0]
friends.append('STR')
print(friends)
# Out:
# ['sha', 1, 1, 3.0, 'STR']

# %%
friends.insert(1, 'gyt')
print(friends)
# Out:
# ['sha', 'gyt', 1, 1, 3.0, 'STR', 'S', 'T', 'R']

# %%
friends.insert(0, 'hii') # not replaceing
print(friends)
# Out:
# ['hii', 'hey', 'hey', 'hey', 'hey', 'hey', 'sha', 1, 1, 3.0, 5, 6, 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S']

# %%
type[friends]
# Out:
# type[['hii', 'hey', 'hey', 'hey', 'hey', 'hey', 'sha', 1, 1, 3.0, 5, 6, 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S']]

# %%
print('this is the output of the list', friends)
# Out:
# this is the output of the list ['hii', 'hey', 'hey', 'hey', 'hey', 'hey', 'sha', 1, 1, 3.0, 5, 6, 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S']

# %%
new_friends = ('harsh', 'renu', 'leva')
friends.extend(new_friends)
print(friends)
# Out:
# ['hii', 'hey', 'hey', 'hey', 'hey', 'hey', 'sha', 1, 1, 3.0, 5, 6, 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'T', 'R', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'harsh', 'renu', 'leva']

# %%
Marks= [98.99.94]

# %%
name=['shashi', 2, 'key']

# %%
name[0] = 'pandit'
print(name)
name[2] = 'r'
print(name)
# Out:
# ['pandit', 2, 'key']
# ['pandit', 2, 'r']

# %%
name.pop() #pop remove last element is (2)than remove 2nd position
# Out:
# 'r'

# %%
print(name)
# Out:
# ['pandit', 2]

# %%
name.remove('pandit')

# %%
nums = [3, 1, 4, 2]
nums.reverse()
print(nums)
# Out:
# [2, 4, 1, 3]

# %%
nums = [3, 1, 4, 2]
reversed_nums = nums[::-1] # reverse using slice
print(reversed_nums)
# Out:
# [2, 4, 1, 3]

# %%
nums = [6,7,3,1,8] 
nums.sort()  #ascending order
print(nums)
# Out:
# [1, 3, 6, 7, 8]

# %%
nums.sort(reverse=True) #descending order
print(nums)
# Out:
# [8, 7, 6, 3, 1]
