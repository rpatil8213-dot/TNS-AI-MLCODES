# %%
#empty Dictionary
empty_dict ={}
empty_dict = dic{}

# %%
# creating Dictionary (dic is pair )

countries = {'India': 'inr', 'China':'chinese_pound'}
countries
# Out:
# {'India': 'inr', 'China': 'chinese_pound'}

# %%
type(countries)
# Out:
# dict

# %%
countries_1 = {'India:inr', 'China:chinese_pound'}

# %%
type(countries_1)
# Out:
# set

# %%
# rtrieving element from a dic
countries['India'] # retriving element we will give keys to the dic
# Out:
# 'inr'

# %%
countries
# Out:
# {'India': 'inr', 'China': 'chinese_pound'}

# %%
#adding new element to dic
countries['USA'] = 'dollar' 
countries
# Out:
# {'India': 'Rs', 'China': 'chinese_pound', 'USA': 'dollar'}

# %%
#modifying dic
countries['India'] = 'Rs'
countries
# Out:
# {'India': 'Rs', 'China': 'chinese_pound'}

# %%
#dic.update()- insert the specified items to the dic
new_countries = {'Singapore':'SGD', 'Indonesia':'IDR','Thailand':'Thai_bhat'}
countries.update(new_countries)
print(countries)
# Out:
# {'India': 'Rs', 'China': 'chinese_pound', 'USA': 'dollar', 'Singapore': 'SGD', 'Indonesia': 'IDR', 'Thailand': 'Thai_bhat'}

# %%
# remove element from dic
countries.pop("USA")
#we will mention key to remove
# Out:
# 'dollar'

# %%
countries

{'India':'Rs',
 'China':'chinese_pound',
 'Singapore':'SGD',
 'Indonesia':'IDR',
 'Thailand':'Thai_bhat'}
# Out:
# {'India': 'Rs',
#  'China': 'chinese_pound',
#  'Singapore': 'SGD',
#  'Indonesia': 'IDR',
#  'Thailand': 'Thai_bhat'}

# %%
countries.popitem()
# Out:
# ('Indonesia', 'IDR')

# %%
#function /operations on dic
##iteration_ for loop, dic.keys(),dic.values(), membership, len(), sorted()

# %%
#iterating over a dic
countries

{'India':'Rs',
 'China':'chinese_pound',
 'Singapore':'SGD',
 'Indonesia':'IDR'}
# Out:
# {'India': 'Rs',
#  'China': 'chinese_pound',
#  'Singapore': 'SGD',
#  'Indonesia': 'IDR'}

# %%
countries.keys()  # it is asequence
# Out:
# dict_keys(['India', 'China', 'USA', 'Singapore', 'Indonesia'])

# %%
countries.values()
# Out:
# dict_values(['Rs', 'chinese_pound', 'dollar', 'SGD', 'IDR'])

# %%
countries.items()  #keys and values in the dictionary
# Out:
# dict_items([('India', 'Rs'), ('China', 'chinese_pound'), ('USA', 'dollar'), ('Singapore', 'SGD'), ('Indonesia', 'IDR')])

# %%
set(countries.keys())  # it gives keys in a list
# Out:
# {'China', 'India', 'Indonesia', 'Singapore', 'USA'}

# %%
# membership
my_dic = {'a':1, 'b':2, 'c':3}
# using 'in' operator to check membership of keys
if 'b' in my_dic.values():
    print("key 'b'is exists ")

# %%
if 3 in my_dic.values():
    print("Value 3 exists in the dictionary")
# Out:
# Value 3 exists in the dictionary

# %%
#size/counting and sorting
my_dic = {'a':1, 'b':2, 'c':3} # using len() to get the number of key values pairs in the dic
print(len(my_dic))
# Out:
# 3

# %%
#using sorted() to sort the dictionary keys
sorted_keys = sorted(my_dic.keys())
print(sorted_keys)
# Out:
# ['a', 'b', 'c']

# %%
# ZIP combine both list on index wise and creae a sequence of tuples
l1=['rasool','arun','aasik','prasanth']
l2=[1,2,12,4]

new_list=set(zip(l1,l2))
new_list
# Out:
# {('aasik', 12), ('arun', 2), ('prasanth', 4), ('rasool', 1)}

# %%
names = ["ALIce","Bob", "Charile"]
ages = [30, 25, 35]

person_info = dict(zip(names, ages))
print(person_info)
# Out:
# {'ALIce': 30, 'Bob': 25, 'Charile': 35}

# %%
# if else staement
num = int(input('enter the num- '))
if num>0:
     print('Positive')
else:
     print('Negative')
# Out:
# Negative

# %%
#palindrame check
word =eval(input('enter the word: '))
if word == word[::-1]:
    print('match')
else:
    print('donot match')
# Out:
# donot match

# %%
num =49
if num%7 ==0:
    print('div')
else:
    print('not div')
# Out:
# div

# %%
# nested if... else... - statement more than two conditions
num= 34
if num>0:
    if num%5 ==0:
     print('Positive,Number is divisible by 5')
    else:
     print('Positive,Number is not divisible by 5')
else:
    print('Negative')
# Out:
# Positive,Number is not divisible by 5

# %%
num1= int(input('enter your number:'))
num2= int(input('enter your number:'))

if num1>num2:
    if num1%2==0:
        print(num1,'is maximum,it is even')
    else:
        print(num1,'is maximum,it is odd')
else:
    if num2%2==0:
        print(num2,'is maximum,it is even')
    else:
        print(num2,'is maximum,it is odd')
# Out:
# 5 is maximum,it is odd

# %%
num= int (input('enter your number'))
if num>0:
    print(num, 'Positive')
elif num ==0:
    print(num,'Zero')
else:
    print(num,'Negative')
# Out:
# 7 Positive

# %%
# Automated Customer Support Response System

# A system thst provide automsted responses to costomer inquiries based on the cintent of the message

# %%
def generate_response(customer_message):
    if"refund"in customer_messsage:
        return"we're sorry to hear that you need a refund. Please provide your order number and we' ll process it for you."
    elif"delivery"in customer_message:
        return"Your order is on its way! You can track your delivery using the tracking number provided in your email."
    elif "product" in customer_message:
        return "Can you please specify which product you are inquiring about? We'll be happy to assist you further."
    else:
        return "Thank you for reaching out to us. How can we assist you today?"

# ex

customer_message = "I would like to inquire about the delivery status of my order."
response = generate_response("customer_message")
print("Automated Response:", response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 14
#      11 # ex
#      13 customer_message = "I would like to inquire about the delivery status of my order."
# ---> 14 response = generate_response("customer_message")
#      15 print("Automated Response:", response)
#
# Cell In[109], line 2, in generate_response(customer_message)
#       1 def generate_response(customer_message):
# ----> 2     if"refund"in customer_messsage:
#       3         return"we're sorry to hear that you need a refund. Please provide your order number and we' ll process it for you."
#       4     elif"delivery"in customer_message:
#
# NameError: name 'customer_messsage' is not defined
