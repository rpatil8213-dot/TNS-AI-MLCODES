# %%
#1.Create two numbers and print their addition.
a=2
b=4
sum = a+b
print(sum)
# Out:
# 6

# %%
#2.Create two numbers and print their multiplication.
a=789
b= 675
mul=a*b
print(mul)
# Out:
# 532575

# %%
#3,Convert a float value 56.78 into an integer.
value = 56.78
integer_value = int(value)

print(integer_value)
integer_value1 = round(value) # round fig value nearest 
print(integer_value1)
# Out:
# 56
# 57

# %%
#4.Find the average of three numbers 10, 20, and 30.
num1 = 10
num2 = 20
num3 = 30

average = (num1 + num2 + num3) / 3

print("Average:", average)
# Out:
# Average: 20.0

# %%
#5.create a string 'python' and print three times
str=('Python')
print(str)
print(str)
print(str)
# Out:
# Python
# Python
# Python

# %%
#6.Create a string 'Data Science' and print its length
str1=('Data Science')
len(str1)
# Out:
# 12

# %%
#7.Convert the string 'machine learning' into uppercase
str=('machine learing')
uppercase_str=str.upper()
print(uppercase_str)
print("machine learning".upper()) # short from
# Out:
# MACHINE LEARING
# MACHINE LEARNING

# %%
#8. Join two strings 'Hello' and 'Students'.
str1=('Hello')
str2=('Student')
print(str1+str2)
# Out:
# HelloStudent

# %%
#9. Create a list [10, 20, 30, 40] and print the first element.
lis=[10,20,30,40]
lis[0]
# Out:
# 10

# %%
#10.Add value 50 to the list [10, 20, 30, 40].
list=[10,20,30,40]
list.append('50')
print(list)
# Out:
# [10, 20, 30, 40, '50']

# %%
#11. Remove the last element from the list [1, 2, 3, 4].
list = [1,2,3,4]
list.pop()  
print(list)
# Out:
# [1, 2, 3]

# %%
lis = ['1', '2', '3', '4']
lis.remove('4')
print(lis)
# Out:
# ['1', '2', '3']

# %%
#12. Sort the list [40, 10, 30, 20].
lis1 = [40, 10, 30, 20]
lis1.sort()
print(lis1)
# Out:
# [10, 20, 30, 40]

# %%
#13. Create a tuple (5, 10, 15, 20) and print its length
tup = (5, 10, 15, 20)
len(tup)
# Out:
# 4

# %%
#14. Count how many times 10 appears in the tuple (10, 20, 10, 30, 10).
tup = (10, 20, 10, 30, 10)
tup.count(10)
# Out:
# 3

# %%
#15. Find the index of value 30 in the tuple (10, 20, 30, 40).
tup = (10, 20, 30, 40)
tup.index(30)
# Out:
# 2

# %%
#16. Create a set {1, 2, 2, 3, 4} and print the set.
set= {1, 2, 3, 4}
print(set)
# Out:
# {1, 2, 3, 4}

# %%
#17.  add the value 5 in the set {1, 2, 3, 4}
set.add(5)
print(set)
# Out:
# {1, 2, 3, 4, 5}

# %%
#18. Find the union of sets {1,2,3} and {3,4,5}.
s1 = {1, 2, 3}
s2 = {3, 4, 5}
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5}

# %%
s1|s2
# Out:
# {1, 2, 3, 4, 5}

# %%
#19. Create a dictionary {'Name':'Ravi','Age':21,'Course':'Python'} and print all keys.
student = {'Name': 'Ravi', 'Age': 21, 'Course': 'Python'}
print(student.keys())
# Out:
# dict_keys(['Name', 'Age', 'Course'])

# %%
#20.  Print all values from the dictionary {'Name':'Ravi','Age':21,'Course':'Python'}.
print(student)
# Out:
# {'Name': 'Ravi', 'Age': 21, 'Course': 'Python'}
