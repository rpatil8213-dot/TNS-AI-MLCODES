# %%
pip install easygui
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import easygui

# %%
path=easygui.fileopenbox()

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info()      # technical info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df['years']=df['YearsExperience'].astype(int)  # To change the datatypes

# %%
df
# Out:
#     YearsExperience    Salary  years
# 0                 1   39343.0      1
# 1                 1   46205.0      1
# 2                 1   37731.0      1
# 3                 2   43525.0      2
# 4                 2   39891.0      2
# 5                 2   56642.0      2
# 6                 3   60150.0      3
# 7                 3   54445.0      3
# 8                 3   64445.0      3
# 9                 3   57189.0      3
# 10                3   63218.0      3
# 11                4   55794.0      4
# 12                4   56957.0      4
# 13                4   57081.0      4
# 14                4   61111.0      4
# 15                4   67938.0      4
# 16                5   66029.0      5
# 17                5   83088.0      5
# 18                5   81363.0      5
# 19                6   93940.0      6
# 20                6   91738.0      6
# 21                7   98273.0      7
# 22                7  101302.0      7
# 23                8  113812.0      8
# ...

# %%
df["YearsExperience"]=df['YearsExperience'].astype(int)   # To chnage data types
df
# Out:
#     YearsExperience    Salary  years
# 0                 1   39343.0      1
# 1                 1   46205.0      1
# 2                 1   37731.0      1
# 3                 2   43525.0      2
# 4                 2   39891.0      2
# 5                 2   56642.0      2
# 6                 3   60150.0      3
# 7                 3   54445.0      3
# 8                 3   64445.0      3
# 9                 3   57189.0      3
# 10                3   63218.0      3
# 11                4   55794.0      4
# 12                4   56957.0      4
# 13                4   57081.0      4
# 14                4   61111.0      4
# 15                4   67938.0      4
# 16                5   66029.0      5
# 17                5   83088.0      5
# 18                5   81363.0      5
# 19                6   93940.0      6
# 20                6   91738.0      6
# 21                7   98273.0      7
# 22                7  101302.0      7
# 23                8  113812.0      8
# ...

# %%
df.head()
# Out:
#    YearsExperience   Salary  years
# 0                1  39343.0      1
# 1                1  46205.0      1
# 2                1  37731.0      1
# 3                2  43525.0      2
# 4                2  39891.0      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     int64
#  1   Salary           30 non-null     float64
#  2   years            30 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 852.0 bytes

# %%
df.drop('YearsExperience', axis=1, inplace=True)  # axis 1 for columns, 0 for rows

# %%
df.head()
# Out:
#     Salary  years
# 0  39343.0      1
# 1  46205.0      1
# 2  37731.0      1
# 3  43525.0      2
# 4  39891.0      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  30 non-null     float64
#  1   years   30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
print('Number of Rows and Columns:', df.shape)
# Out:
# Number of Rows and Columns: (30, 2)

# %%
df['years'].describe()  #stastical info of the given column
# Out:
# count    30.000000
# mean      4.933333
# std       2.790789
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       7.000000
# max      10.000000
# Name: years, dtype: float64

# %%
df.describe()
# Out:
#               Salary      years
# count      30.000000  30.000000
# mean    76003.000000   4.933333
# std     27414.429785   2.790789
# min     37731.000000   1.000000
# 25%     56720.750000   3.000000
# 50%     65237.000000   4.000000
# 75%    100544.750000   7.000000
# max    122391.000000  10.000000

# %%
df
# Out:
#       Salary  years
# 0    39343.0      1
# 1    46205.0      1
# 2    37731.0      1
# 3    43525.0      2
# 4    39891.0      2
# 5    56642.0      2
# 6    60150.0      3
# 7    54445.0      3
# 8    64445.0      3
# 9    57189.0      3
# 10   63218.0      3
# 11   55794.0      4
# 12   56957.0      4
# 13   57081.0      4
# 14   61111.0      4
# 15   67938.0      4
# 16   66029.0      5
# 17   83088.0      5
# 18   81363.0      5
# 19   93940.0      6
# 20   91738.0      6
# 21   98273.0      7
# 22  101302.0      7
# 23  113812.0      8
# 24  109431.0      8
# 25  105582.0      9
# 26  116969.0      9
# 27  112635.0      9
# 28  122391.0     10
# 29  121872.0     10

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.0 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/8.1 MB 1.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.1 MB 1.0 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.1 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.0 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.0 MB/s eta 0:00:07
#    --------- ------------------------------ 1.8/8.1 MB 824.6 kB/s eta 0:00:08
#    --------- ------------------------------ 1.8/8.1 MB 824.6 kB/s eta 0:00:08
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop('Salary',axis=1)   #independent variables
y=df['Salary']  # target/ dependent variable

# %%
pip install statsmodels
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 946.0 kB/s eta 0:00:10
#    --- ------------------------------------ 0.8/9.6 MB 992.5 kB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.6 MB 1.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.6 MB 1.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.6 MB 936.9 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.6 MB 932.1 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.6 MB 932.1 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.6 MB 894.3 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.6 MB 922.5 kB/s eta 0:00:09
# ...

# %%
import statsmodels.api as sm

# %%
x_with_constant = sm.add_constant(x)
x_with_constant
# Out:
#     const  years
# 0     1.0      1
# 1     1.0      1
# 2     1.0      1
# 3     1.0      2
# 4     1.0      2
# 5     1.0      2
# 6     1.0      3
# 7     1.0      3
# 8     1.0      3
# 9     1.0      3
# 10    1.0      3
# 11    1.0      4
# 12    1.0      4
# 13    1.0      4
# 14    1.0      4
# 15    1.0      4
# 16    1.0      5
# 17    1.0      5
# 18    1.0      5
# 19    1.0      6
# 20    1.0      6
# 21    1.0      7
# 22    1.0      7
# 23    1.0      8
# 24    1.0      8
# 25    1.0      9
# 26    1.0      9
# 27    1.0      9
# 28    1.0     10
# 29    1.0     10

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: Salary, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x_with_constant, y, test_size=0.3, random_state=30)

# %%
x_test.head()
# Out:
#     const  years
# 15    1.0      4
# 28    1.0     10
# 26    1.0      9
# 10    1.0      3
# 24    1.0      8

# %%
x_train.index
# Out:
# Index([4, 11, 22, 18, 19, 1, 16, 7, 9, 3, 14, 17, 21, 2, 23, 12, 20, 27, 13,
#        29, 5],
#       dtype='int64')

# %%
import statsmodels.api as sm

# %%
model=sm.OLS(y_train,x_train).fit()    # statsmodel stastical model-- OLS (Ordinary Least Square)
model.summary()                        # sklearn- linear regression      # r squared value should be minimum
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.927
# Method:                 Least Squares   F-statistic:                     256.3
# Date:                Mon, 23 Mar 2026   Prob (F-statistic):           1.74e-12
# Time:                        19:46:23   Log-Likelihood:                -214.92
# No. Observations:                  21   AIC:                             433.8
# Df Residuals:                      19   BIC:                             435.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.624e+04   3298.359      7.954      0.000    1.93e+04    3.31e+04
# ...

# %%
pred_train=

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

# %%
train_rmse=np.sqrt(mean_squared_error(y_train,pred_train))
test_rmse=np.sqrt(mean_squared_error(ytest,pred_test))
print(f'Train RMSE:{train_rmse}')
print(f'Test RMSE:{test_rmse}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 train_rmse=np.sqrt(mean_squared_error(y_train,pred_train))
#       2 test_rmse=np.sqrt(mean_squared_error(ytest,pred_test))
#       3 print(f'Train RMSE:{train_rmse}')
#
# NameError: name 'pred_train' is not defined

# %%
model_1=LinearRegression()
model_1.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_train_1=model_1.predict(x_train)
pred_test_1=model_1.predict(x_test)

# %%
pred_train_1
# Out:
# array([ 46228.93042191,  66222.33974833,  96212.45373797,  76219.04441155,
#         86215.74907476,  36232.2257587 ,  76219.04441155,  56225.63508512,
#         56225.63508512,  46228.93042191,  66222.33974833,  76219.04441155,
#         96212.45373797,  36232.2257587 , 106209.15840118,  66222.33974833,
#         86215.74907476, 116205.8630644 ,  66222.33974833, 126202.56772761,
#         46228.93042191])

# %%
pred_test_1
# Out:
# array([ 66222.33974833, 126202.56772761, 116205.8630644 ,  56225.63508512,
#        106209.15840118,  36232.2257587 ,  56225.63508512,  56225.63508512,
#        116205.8630644 ])
